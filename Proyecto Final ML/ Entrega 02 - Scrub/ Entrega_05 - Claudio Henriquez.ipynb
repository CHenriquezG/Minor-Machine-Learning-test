# %% [markdown]
# <a href="https://colab.research.google.com/github/CHenriquezG/Minor-Machine-Learning-test/blob/main/Proyecto%20Final%20ML/%20Entrega%2002%20-%20Scrub/%20Entrega_05%20-%20Claudio%20Henriquez.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Proyecto Final - Reconocimiento de Actividad Humana (HAR)

# %% [markdown]
# nombre: Claudio henriquez

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils import resample

# %% [markdown]
# ###Entrega 01 - OBTAIN

# %% [markdown]
# Incluir todo el código de la Etapa 01 - OBTAIN creada en la semana anterior

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
columna = ["user","activity","timestamp","x-acceleration","y-accel","z-accel"]
dataset=pd.read_table('/content/drive/MyDrive/ml/WISDM_ar_v1.1_raw.txt',sep=",",
                      header=None,
                      names=columna)

# se remueve el punto y coma en el "z"
dataset['z-accel'] = dataset['z-accel'].str.replace(";", "")
dataset.head()
# Out:
#    user activity       timestamp  x-acceleration    y-accel      z-accel
# 0    33  Jogging  49105962326000       -0.694638  12.680544   0.50395286
# 1    33  Jogging  49106062271000        5.012288  11.264028   0.95342433
# 2    33  Jogging  49106112167000        4.903325  10.882658  -0.08172209
# 3    33  Jogging  49106222305000       -0.612916  18.496431    3.0237172
# 4    33  Jogging  49106332290000       -1.184970  12.108489     7.205164

# %% [markdown]
# ###Entrega 02 - SCRUB

# %% [markdown]
# Eliminar filas con datos faltantes

# %% [markdown]
# *Uno de los pasos iniciales en la limpieza de datos consiste en eliminar aquellas filas que contengan datos faltantes. Estas líneas generalmente no aportan información y pueden complicar la etapa de entrenamiento y validación de muchos modelos predictivos.*

# %%
datasetCopy = dataset.copy(deep = True)
datasetCopy[["user","activity","timestamp","x-acceleration","y-accel","z-accel"]] =datasetCopy[["user","activity","timestamp","x-acceleration","y-accel","z-accel"]].replace(0,np.NaN) 
datasetCopy.isnull().sum()
# Out:
# user                  0
# activity              0
# timestamp         12843
# x-acceleration    16511
# y-accel           13999
# z-accel               1
# dtype: int64

# %%
datasetCopy = datasetCopy.dropna()
datasetCopy.isnull().sum()
# Out:
# user              0
# activity          0
# timestamp         0
# x-acceleration    0
# y-accel           0
# z-accel           0
# dtype: int64

# %% [markdown]
# Agregar al DataFrame los nombres de las columnas

# %% [markdown]
# *En ocasiones al crear los data frames el sistema asigna nombres genéricos y correlativos a las columnas. Es recomendable renombrar las columnas por nombres significativos para favorecer el análisis posterior de los datos.*

# %%
dataset = datasetCopy
columnasR = ["user","activity","time","x","y","z"]
dataset.columns = columnasR
dataset.head()
# Out:
#    user activity          time         x          y            z
# 0    33  Jogging  4.910596e+13 -0.694638  12.680544   0.50395286
# 1    33  Jogging  4.910606e+13  5.012288  11.264028   0.95342433
# 2    33  Jogging  4.910611e+13  4.903325  10.882658  -0.08172209
# 3    33  Jogging  4.910622e+13 -0.612916  18.496431    3.0237172
# 4    33  Jogging  4.910633e+13 -1.184970  12.108489     7.205164

# %% [markdown]
# Visualizar las 5 primeras filas del DataFrame (.head())

# %% [markdown]
# *Siempre es buena medida visualizar algunas líneas del dataframe para tener una idea concreta del contenido.*

# %%
dataset.head()
# Out:
#    user activity          time         x          y            z
# 0    33  Jogging  4.910596e+13 -0.694638  12.680544   0.50395286
# 1    33  Jogging  4.910606e+13  5.012288  11.264028   0.95342433
# 2    33  Jogging  4.910611e+13  4.903325  10.882658  -0.08172209
# 3    33  Jogging  4.910622e+13 -0.612916  18.496431    3.0237172
# 4    33  Jogging  4.910633e+13 -1.184970  12.108489     7.205164

# %% [markdown]
# Buscar datos nulos y eliminarlos si es que existen

# %%
datasetCopy.isnull().sum()
# Out:
# user        0
# activity    0
# time        0
# x           0
# y           0
# z           0
# dtype: int64

# %% [markdown]
# Visualizar los tipo de datos a los que pertenece cada columna (.info())

# %% [markdown]
# *Es necesario tener un detalle de cuantas variables están considerando y el tipo de datos que pertenecen para verificar si es posible utilizarla directamente para el modelo predictivo o si es necesario realizar una transformación del tipo de dato.*

# %%
dataset.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1080536 entries, 0 to 1098203
# Data columns (total 6 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   user      1080536 non-null  int64
#  1   activity  1080536 non-null  object
#  2   time      1080536 non-null  float64
#  3   x         1080536 non-null  float64
#  4   y         1080536 non-null  float64
#  5   z         1080536 non-null  object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 57.7+ MB

# %% [markdown]
# Cambiar el tipo de datos de las variables predictoras a valores reales, para realizar la clasificación

# %% [markdown]
# *Muchas de las variables contenidas en el DataFrame originalmente se encuentran en el tipo de dato 'object'. En ese formato las variables no pueden ser interpretadas como vectores. Recordemos que la mayoría de los modelos de Machine Learning estudiados operan en el espacio vectorial. Por esta razón las variables que formarán parte del modelo predictivo deben ser transformadas a un formato numérico como 'Float' o 'integer'.*
#
# Para este proyecto en particular se pide transformar  al tipo de dato Float, las variables del acelerómetro en el eje $x$, $y$ y $z$

# %%
lb = LabelEncoder()
dataset["z"] = pd.to_numeric(dataset["z"])

dataset.head()
# Out:
#    user activity          time         x          y         z
# 0    33  Jogging  4.910596e+13 -0.694638  12.680544  0.503953
# 1    33  Jogging  4.910606e+13  5.012288  11.264028  0.953424
# 2    33  Jogging  4.910611e+13  4.903325  10.882658 -0.081722
# 3    33  Jogging  4.910622e+13 -0.612916  18.496431  3.023717
# 4    33  Jogging  4.910633e+13 -1.184970  12.108489  7.205164

# %% [markdown]
# Imprimir los tipos de datos de las variables del DataFrame

# %% [markdown]
# *Se recomienda volver a ejecutar el comando info para verificar que efectivamente las variables cambiaron su tipo de dato y que ahora se pueden procesar con los modelos predictivos.*

# %%
dataset.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1080536 entries, 0 to 1098203
# Data columns (total 6 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   user      1080536 non-null  int64
#  1   activity  1080536 non-null  object
#  2   time      1080536 non-null  float64
#  3   x         1080536 non-null  float64
#  4   y         1080536 non-null  float64
#  5   z         1080536 non-null  float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 57.7+ MB

# %% [markdown]
# Eliminar las columnas que no se utilizaran para la clasificación

# %% [markdown]
# *En este caso deberíamos conservar la actividad respectiva y las variables asociadas al acelerómetro*

# %%
#se elimino time y user
copia = dataset.copy()
dataset = dataset.drop(['time'], axis=1)
#dataset = dataset.drop(['user'], axis=1)
dataset.head()
# Out:
#    user activity         x          y         z
# 0    33  Jogging -0.694638  12.680544  0.503953
# 1    33  Jogging  5.012288  11.264028  0.953424
# 2    33  Jogging  4.903325  10.882658 -0.081722
# 3    33  Jogging -0.612916  18.496431  3.023717
# 4    33  Jogging -1.184970  12.108489  7.205164

# %% [markdown]
# Utilizar el comando *value_counts* para obtener un detalle de cuantas instancias se tienen por actividad. El objetivo consiste en identificar la presencia del balance o desbalance en las categorías a modelar

# %%
dataset.value_counts("activity")

# aca se puede ver que standing es el menor
# Out:
# activity
# Walking       422301
# Jogging       329114
# Upstairs      121934
# Downstairs     99693
# Sitting        59462
# Standing       48032
# dtype: int64

# %%
#dataset.drop(dataset[(dataset['user'] != 19)].index, inplace=True)

# %% [markdown]
# Este proyecto considera datos con un desbalance de clases. Es necesario balancearlos para que los modelos operen de manera adecuada. Existen muchas maneras de realizar un balance, pero en este proyecto utilizaremos una estrategia sencilla e intuitiva. Simplemente debe identificar la actividad que contenga el número menor de instancias. Se debe realizar un muestreo para las otras actividades utilizando ese valor. De esta manera todas las clases tendrán la misma cantidad de instancias.

# %%
x1 = dataset[dataset["activity"] == "Standing"]
x2 = dataset[dataset["activity"] == "Jogging"]

new = dataset.groupby('activity', as_index=False).apply(lambda x: x.sample(n=len(x1))).reset_index(drop=True)
#juntamos todo


#dataset.value_counts("activity")

# %% [markdown]
# Establecer el número de instancias y dimensiones del data frame resultante *(shape)*

# %%
new.shape
# Out:
# (288192, 5)

# %% [markdown]
# Volver a imprimir la cantidad de instancias por categoría para verificar que todo esté en orden. *(value_counts)*

# %%
new.value_counts("activity")
# Out:
# activity
# Downstairs    48032
# Jogging       48032
# Sitting       48032
# Standing      48032
# Upstairs      48032
# Walking       48032
# dtype: int64

# %% [markdown]
# Volver a visualizar las cinco primeras líneas del DataFrame para revisar que todo esté en orden *(head)*

# %%
new.head()
# Out:
#    user    activity     x      y         z
# 0    15  Downstairs -4.02   8.73 -1.225831
# 1    36  Downstairs -0.04  10.31  2.492524
# 2     5  Downstairs -0.11   5.28 -0.299648
# 3    11  Downstairs  2.30  -8.01  0.721878
# 4    17  Downstairs  0.53   9.34 -1.140000

# %% [markdown]
# Separar las variables predictoras (X) de las ctegorias o etiquetas (y)

# %%
xa = new['activity']
ya = new.drop(['activity'], axis=1)
xu = new['user']
yd = ya.drop(['user'], axis=1)
xt = pd.concat([xa, xu], axis=1).reindex(xa.index)
yd
# Out:
#             x      y         z
# 0       -4.02   8.73 -1.225831
# 1       -0.04  10.31  2.492524
# 2       -0.11   5.28 -0.299648
# 3        2.30  -8.01  0.721878
# 4        0.53   9.34 -1.140000
# ...       ...    ...       ...
# 288187   4.18  12.76 -1.566340
# 288188  11.07  13.02  1.230000
# 288189   2.15  10.95  4.058864
# 288190  15.79  19.00  0.270000
# 288191  -0.31  11.56 -2.720000
#
# [288192 rows x 3 columns]

# %% [markdown]
# Estandarizar los datos numericos (*StandardScaler)*

# %% [markdown]
# *Para el caso de la estandarización de los datos se pueden usar distintas técnicas, como la normalización 01, estandarización entre -1 y 1 o el denominado Z-Score. En este caso usaremos la función Standard Scaler de Python con sus valores por defecto.*

# %%
scaler = StandardScaler()
escalado = scaler.fit_transform(yd)

yd = pd.DataFrame(escalado)
columnasR = ["x","y","z"]
yd.columns = columnasR
yd.head()
# Out:
#           x         y         z
# 0 -0.752839  0.290428 -0.553064
# 1 -0.087618  0.557067  0.254750
# 2 -0.099318 -0.291792 -0.351850
# 3  0.303491 -2.534602 -0.129923
# 4  0.007652  0.393371 -0.534417

# %% [markdown]
# Como último paso debe reconstruir el dataframe pegando las columnas de los variables predicadores (X) y las categorías (y)

# %%
xd = pd.DataFrame(xa)
xd = xd.reset_index(drop=True)
datafinal = pd.concat([xd, yd], axis=1).reindex(xd.index)
yd = datafinal
xd = pd.DataFrame(xu)
xd = xd.reset_index(drop=True)
datafinal = pd.concat([xd, yd], axis=1).reindex(xd.index)
datafinal.head()
# Out:
#    user    activity         x         y         z
# 0    15  Downstairs -0.752839  0.290428 -0.553064
# 1    36  Downstairs -0.087618  0.557067  0.254750
# 2     5  Downstairs -0.099318 -0.291792 -0.351850
# 3    11  Downstairs  0.303491 -2.534602 -0.129923
# 4    17  Downstairs  0.007652  0.393371 -0.534417

# %% [markdown]
# # Entrega 03 - Explore

# %%
datafinal.head()
# Out:
#    user    activity         x         y         z
# 0    15  Downstairs -0.752839  0.290428 -0.553064
# 1    36  Downstairs -0.087618  0.557067  0.254750
# 2     5  Downstairs -0.099318 -0.291792 -0.351850
# 3    11  Downstairs  0.303491 -2.534602 -0.129923
# 4    17  Downstairs  0.007652  0.393371 -0.534417

# %% [markdown]
# en el siguiente grafico podemos observar que existe pocos datos entorno a Siting, Standing, downstairs por lo que puede provocar ineficacia

# %%
plt.figure(figsize=(16,8))
plt.title('Histograma de actividades por usuario', fontsize=20)
sns.countplot(x='user',hue='activity', data = datafinal)
plt.show()

# %% [markdown]
# este otro histograma se clasifica por actividades identificando mas claro las cantidades,donde el valor es de 48032 para cada actuvidad

# %%
plt.title('Instancias por Actividad', fontsize=15)
sns.countplot(datafinal.activity)
plt.xticks(rotation=90)
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
datafinal.activity.value_counts()
# Out:
# Downstairs    48032
# Jogging       48032
# Sitting       48032
# Standing      48032
# Upstairs      48032
# Walking       48032
# Name: activity, dtype: int64

# %% [markdown]
# en los siguientes 3 histogramas de frecuencia se graficaron las columnas de las aceleraciones en x,y,z y lo que nos dio fue que
# para x los valores que se destacan es entre el -5 y 5
# para y los valores de la grafica se destacael intervalo 5 y 10
# para z los valores de la grafica se destaca el nitervalo -5 -y 5

# %%
plt.hist(datafinal.x)
# Out:
# (array([ 4376.,  3845., 10046., 37736., 92912., 69909., 42049., 17488.,
#          5458.,  4373.]),
#  array([-3.35605579, -2.69495838, -2.03386097, -1.37276356, -0.71166614,
#         -0.05056873,  0.61052868,  1.27162609,  1.93272351,  2.59382092,
#          3.25491833]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(datafinal.y)
# Out:
# (array([ 1041.,   974.,  2088.,  5508., 29163., 47266., 61293., 95037.,
#         27959., 17863.]),
#  array([-4.49484853, -3.82519568, -3.15554282, -2.48588997, -1.81623712,
#         -1.14658426, -0.47693141,  0.19272144,  0.8623743 ,  1.53202715,
#          2.20168   ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(datafinal.z)
# Out:
# (array([   340.,   1460.,   4740.,  19503.,  89677., 101283.,  33217.,
#          35100.,   2302.,    570.]),
#  array([-4.57891364, -3.72299712, -2.86708061, -2.0111641 , -1.15524759,
#         -0.29933108,  0.55658544,  1.41250195,  2.26841846,  3.12433497,
#          3.98025149]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# otro histograma nos muestra la distribucion de datos lineal, y los datos que se pueden destacar es la de standing en la que se concentra entorno al intervalo 6 y 10, y no tiene presencia en en intervalo 10 y 20 , y -10  y 0

# %%
sns.set_palette("Set1", desat=0.80)
facetgrid = sns.FacetGrid(datafinal, hue='activity', size=6,aspect=2)
facetgrid.map(sns.distplot,'y', hist=False)\
    .add_legend()
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
#Algunos valores atípicos a tener en cuenta
plt.figure(figsize=(10,4))

g = sns.regplot(x='x', y='activity', data=datafinal, x_jitter=True, fit_reg=False)
g.set_title("Points/Price Distribution", fontsize=20)
g.set_xlabel("Points", fontsize= 15)
g.set_ylabel("Price", fontsize= 15)

plt.show()

# %% [markdown]
# diagrama de caja entorno al acelerometro y por lo que podemos concluir que:
# si el acelerometro de x,y,z de standing, como se ha visto en otros histogramas, posee un intervalo reducido por lo que puede provocar problemas de eficacia

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='activity', y='y',data=datafinal, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='activity', y='x',data=datafinal, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.boxplot(x='activity', y='y',data=datafinal, showfliers=False, saturation=1)
plt.ylabel('Acceleration Magnitude mean')
plt.xticks(rotation=90)
plt.show()

# %%
from sklearn.manifold import TSNE

def perform_tsne(X_data, y_data, perplexities, n_iter=1000, img_name_prefix='t-sne'):
        
    for index,perplexity in enumerate(perplexities):
        # realizar t-sne
        print('\nperforming tsne with perplexity {} and with {} iterations at max'.format(perplexity, n_iter))
        X_reduced = TSNE(verbose=2, perplexity=perplexity, n_jobs=-1).fit_transform(X_data)
        print('Done..')
        
        # preparar los datos para seaborn         
        print('Creating plot for this t-sne visualization..')
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # dibujar la trama en el lugar apropiado en la cuadrícula
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.title("perplexity : {} and max_iter : {}".format(perplexity, n_iter))
        img_name = img_name_prefix + '_perp_{}_iter_{}.png'.format(perplexity, n_iter)
        print('saving this plot as image in present working directory...')
        plt.savefig(img_name)
        plt.show()
        print('Done')

X_pre_tsne = datafinal.drop(["activity"], axis=1)
y_pre_tsne = datafinal["activity"]

perform_tsne(X_data=X_pre_tsne, y_data=y_pre_tsne, perplexities=[2,5,10,20,50])
# Out:
# performing tsne with perplexity 2 and with 1000 iterations at max
# [t-SNE] Computing 7 nearest neighbors...
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Indexed 255858 samples in 0.431s...
# [t-SNE] Computed neighbors for 255858 samples in 4.007s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 255858
# [t-SNE] Computed conditional probabilities for sample 2000 / 255858
# [t-SNE] Computed conditional probabilities for sample 3000 / 255858
# [t-SNE] Computed conditional probabilities for sample 4000 / 255858
# [t-SNE] Computed conditional probabilities for sample 5000 / 255858
# [t-SNE] Computed conditional probabilities for sample 6000 / 255858
# [t-SNE] Computed conditional probabilities for sample 7000 / 255858
# [t-SNE] Computed conditional probabilities for sample 8000 / 255858
# [t-SNE] Computed conditional probabilities for sample 9000 / 255858
# [t-SNE] Computed conditional probabilities for sample 10000 / 255858
# [t-SNE] Computed conditional probabilities for sample 11000 / 255858
# [t-SNE] Computed conditional probabilities for sample 12000 / 255858
# [t-SNE] Computed conditional probabilities for sample 13000 / 255858
# [t-SNE] Computed conditional probabilities for sample 14000 / 255858
# [t-SNE] Computed conditional probabilities for sample 15000 / 255858
# [t-SNE] Computed conditional probabilities for sample 16000 / 255858
# [t-SNE] Computed conditional probabilities for sample 17000 / 255858
# [t-SNE] Computed conditional probabilities for sample 18000 / 255858
# [t-SNE] Computed conditional probabilities for sample 19000 / 255858
# [t-SNE] Computed conditional probabilities for sample 20000 / 255858
# [t-SNE] Computed conditional probabilities for sample 21000 / 255858
# [t-SNE] Computed conditional probabilities for sample 22000 / 255858
# [t-SNE] Computed conditional probabilities for sample 23000 / 255858
# [t-SNE] Computed conditional probabilities for sample 24000 / 255858
# [t-SNE] Computed conditional probabilities for sample 25000 / 255858
# [t-SNE] Computed conditional probabilities for sample 26000 / 255858
# [t-SNE] Computed conditional probabilities for sample 27000 / 255858
# [t-SNE] Computed conditional probabilities for sample 28000 / 255858
# [t-SNE] Computed conditional probabilities for sample 29000 / 255858
# [t-SNE] Computed conditional probabilities for sample 30000 / 255858
# [t-SNE] Computed conditional probabilities for sample 31000 / 255858
# [t-SNE] Computed conditional probabilities for sample 32000 / 255858
# [t-SNE] Computed conditional probabilities for sample 33000 / 255858
# [t-SNE] Computed conditional probabilities for sample 34000 / 255858
# [t-SNE] Computed conditional probabilities for sample 35000 / 255858
# [t-SNE] Computed conditional probabilities for sample 36000 / 255858
# [t-SNE] Computed conditional probabilities for sample 37000 / 255858
# [t-SNE] Computed conditional probabilities for sample 38000 / 255858
# [t-SNE] Computed conditional probabilities for sample 39000 / 255858
# [t-SNE] Computed conditional probabilities for sample 40000 / 255858
# [t-SNE] Computed conditional probabilities for sample 41000 / 255858
# [t-SNE] Computed conditional probabilities for sample 42000 / 255858
# [t-SNE] Computed conditional probabilities for sample 43000 / 255858
# [t-SNE] Computed conditional probabilities for sample 44000 / 255858
# [t-SNE] Computed conditional probabilities for sample 45000 / 255858
# [t-SNE] Computed conditional probabilities for sample 46000 / 255858
# [t-SNE] Computed conditional probabilities for sample 47000 / 255858
# [t-SNE] Computed conditional probabilities for sample 48000 / 255858
# [t-SNE] Computed conditional probabilities for sample 49000 / 255858
# [t-SNE] Computed conditional probabilities for sample 50000 / 255858
# [t-SNE] Computed conditional probabilities for sample 51000 / 255858
# [t-SNE] Computed conditional probabilities for sample 52000 / 255858
# [t-SNE] Computed conditional probabilities for sample 53000 / 255858
# [t-SNE] Computed conditional probabilities for sample 54000 / 255858
# [t-SNE] Computed conditional probabilities for sample 55000 / 255858
# [t-SNE] Computed conditional probabilities for sample 56000 / 255858
# [t-SNE] Computed conditional probabilities for sample 57000 / 255858
# [t-SNE] Computed conditional probabilities for sample 58000 / 255858
# [t-SNE] Computed conditional probabilities for sample 59000 / 255858
# [t-SNE] Computed conditional probabilities for sample 60000 / 255858
# [t-SNE] Computed conditional probabilities for sample 61000 / 255858
# [t-SNE] Computed conditional probabilities for sample 62000 / 255858
# [t-SNE] Computed conditional probabilities for sample 63000 / 255858
# [t-SNE] Computed conditional probabilities for sample 64000 / 255858
# [t-SNE] Computed conditional probabilities for sample 65000 / 255858
# [t-SNE] Computed conditional probabilities for sample 66000 / 255858
# [t-SNE] Computed conditional probabilities for sample 67000 / 255858
# [t-SNE] Computed conditional probabilities for sample 68000 / 255858
# [t-SNE] Computed conditional probabilities for sample 69000 / 255858
# [t-SNE] Computed conditional probabilities for sample 70000 / 255858
# [t-SNE] Computed conditional probabilities for sample 71000 / 255858
# [t-SNE] Computed conditional probabilities for sample 72000 / 255858
# [t-SNE] Computed conditional probabilities for sample 73000 / 255858
# [t-SNE] Computed conditional probabilities for sample 74000 / 255858
# [t-SNE] Computed conditional probabilities for sample 75000 / 255858
# [t-SNE] Computed conditional probabilities for sample 76000 / 255858
# [t-SNE] Computed conditional probabilities for sample 77000 / 255858
# [t-SNE] Computed conditional probabilities for sample 78000 / 255858
# [t-SNE] Computed conditional probabilities for sample 79000 / 255858
# [t-SNE] Computed conditional probabilities for sample 80000 / 255858
# [t-SNE] Computed conditional probabilities for sample 81000 / 255858
# [t-SNE] Computed conditional probabilities for sample 82000 / 255858
# [t-SNE] Computed conditional probabilities for sample 83000 / 255858
# [t-SNE] Computed conditional probabilities for sample 84000 / 255858
# [t-SNE] Computed conditional probabilities for sample 85000 / 255858
# [t-SNE] Computed conditional probabilities for sample 86000 / 255858
# [t-SNE] Computed conditional probabilities for sample 87000 / 255858
# [t-SNE] Computed conditional probabilities for sample 88000 / 255858
# [t-SNE] Computed conditional probabilities for sample 89000 / 255858
# [t-SNE] Computed conditional probabilities for sample 90000 / 255858
# [t-SNE] Computed conditional probabilities for sample 91000 / 255858
# [t-SNE] Computed conditional probabilities for sample 92000 / 255858
# [t-SNE] Computed conditional probabilities for sample 93000 / 255858
# [t-SNE] Computed conditional probabilities for sample 94000 / 255858
# [t-SNE] Computed conditional probabilities for sample 95000 / 255858
# [t-SNE] Computed conditional probabilities for sample 96000 / 255858
# [t-SNE] Computed conditional probabilities for sample 97000 / 255858
# [t-SNE] Computed conditional probabilities for sample 98000 / 255858
# [t-SNE] Computed conditional probabilities for sample 99000 / 255858
# [t-SNE] Computed conditional probabilities for sample 100000 / 255858
# [t-SNE] Computed conditional probabilities for sample 101000 / 255858
# [t-SNE] Computed conditional probabilities for sample 102000 / 255858
# [t-SNE] Computed conditional probabilities for sample 103000 / 255858
# [t-SNE] Computed conditional probabilities for sample 104000 / 255858
# [t-SNE] Computed conditional probabilities for sample 105000 / 255858
# [t-SNE] Computed conditional probabilities for sample 106000 / 255858
# [t-SNE] Computed conditional probabilities for sample 107000 / 255858
# [t-SNE] Computed conditional probabilities for sample 108000 / 255858
# [t-SNE] Computed conditional probabilities for sample 109000 / 255858
# [t-SNE] Computed conditional probabilities for sample 110000 / 255858
# [t-SNE] Computed conditional probabilities for sample 111000 / 255858
# [t-SNE] Computed conditional probabilities for sample 112000 / 255858
# [t-SNE] Computed conditional probabilities for sample 113000 / 255858
# [t-SNE] Computed conditional probabilities for sample 114000 / 255858
# [t-SNE] Computed conditional probabilities for sample 115000 / 255858
# [t-SNE] Computed conditional probabilities for sample 116000 / 255858
# [t-SNE] Computed conditional probabilities for sample 117000 / 255858
# [t-SNE] Computed conditional probabilities for sample 118000 / 255858
# [t-SNE] Computed conditional probabilities for sample 119000 / 255858
# [t-SNE] Computed conditional probabilities for sample 120000 / 255858
# [t-SNE] Computed conditional probabilities for sample 121000 / 255858
# [t-SNE] Computed conditional probabilities for sample 122000 / 255858
# [t-SNE] Computed conditional probabilities for sample 123000 / 255858
# [t-SNE] Computed conditional probabilities for sample 124000 / 255858
# [t-SNE] Computed conditional probabilities for sample 125000 / 255858
# [t-SNE] Computed conditional probabilities for sample 126000 / 255858
# [t-SNE] Computed conditional probabilities for sample 127000 / 255858
# [t-SNE] Computed conditional probabilities for sample 128000 / 255858
# [t-SNE] Computed conditional probabilities for sample 129000 / 255858
# [t-SNE] Computed conditional probabilities for sample 130000 / 255858
# [t-SNE] Computed conditional probabilities for sample 131000 / 255858
# [t-SNE] Computed conditional probabilities for sample 132000 / 255858
# [t-SNE] Computed conditional probabilities for sample 133000 / 255858
# [t-SNE] Computed conditional probabilities for sample 134000 / 255858
# [t-SNE] Computed conditional probabilities for sample 135000 / 255858
# [t-SNE] Computed conditional probabilities for sample 136000 / 255858
# [t-SNE] Computed conditional probabilities for sample 137000 / 255858
# [t-SNE] Computed conditional probabilities for sample 138000 / 255858
# [t-SNE] Computed conditional probabilities for sample 139000 / 255858
# [t-SNE] Computed conditional probabilities for sample 140000 / 255858
# [t-SNE] Computed conditional probabilities for sample 141000 / 255858
# [t-SNE] Computed conditional probabilities for sample 142000 / 255858
# [t-SNE] Computed conditional probabilities for sample 143000 / 255858
# [t-SNE] Computed conditional probabilities for sample 144000 / 255858
# [t-SNE] Computed conditional probabilities for sample 145000 / 255858
# [t-SNE] Computed conditional probabilities for sample 146000 / 255858
# [t-SNE] Computed conditional probabilities for sample 147000 / 255858
# [t-SNE] Computed conditional probabilities for sample 148000 / 255858
# [t-SNE] Computed conditional probabilities for sample 149000 / 255858
# [t-SNE] Computed conditional probabilities for sample 150000 / 255858
# [t-SNE] Computed conditional probabilities for sample 151000 / 255858
# [t-SNE] Computed conditional probabilities for sample 152000 / 255858
# [t-SNE] Computed conditional probabilities for sample 153000 / 255858
# [t-SNE] Computed conditional probabilities for sample 154000 / 255858
# [t-SNE] Computed conditional probabilities for sample 155000 / 255858
# [t-SNE] Computed conditional probabilities for sample 156000 / 255858
# [t-SNE] Computed conditional probabilities for sample 157000 / 255858
# [t-SNE] Computed conditional probabilities for sample 158000 / 255858
# [t-SNE] Computed conditional probabilities for sample 159000 / 255858
# [t-SNE] Computed conditional probabilities for sample 160000 / 255858
# [t-SNE] Computed conditional probabilities for sample 161000 / 255858
# [t-SNE] Computed conditional probabilities for sample 162000 / 255858
# [t-SNE] Computed conditional probabilities for sample 163000 / 255858
# [t-SNE] Computed conditional probabilities for sample 164000 / 255858
# [t-SNE] Computed conditional probabilities for sample 165000 / 255858
# [t-SNE] Computed conditional probabilities for sample 166000 / 255858
# [t-SNE] Computed conditional probabilities for sample 167000 / 255858
# [t-SNE] Computed conditional probabilities for sample 168000 / 255858
# [t-SNE] Computed conditional probabilities for sample 169000 / 255858
# [t-SNE] Computed conditional probabilities for sample 170000 / 255858
# [t-SNE] Computed conditional probabilities for sample 171000 / 255858
# [t-SNE] Computed conditional probabilities for sample 172000 / 255858
# [t-SNE] Computed conditional probabilities for sample 173000 / 255858
# [t-SNE] Computed conditional probabilities for sample 174000 / 255858
# [t-SNE] Computed conditional probabilities for sample 175000 / 255858
# [t-SNE] Computed conditional probabilities for sample 176000 / 255858
# [t-SNE] Computed conditional probabilities for sample 177000 / 255858
# [t-SNE] Computed conditional probabilities for sample 178000 / 255858
# [t-SNE] Computed conditional probabilities for sample 179000 / 255858
# [t-SNE] Computed conditional probabilities for sample 180000 / 255858
# [t-SNE] Computed conditional probabilities for sample 181000 / 255858
# [t-SNE] Computed conditional probabilities for sample 182000 / 255858
# [t-SNE] Computed conditional probabilities for sample 183000 / 255858
# [t-SNE] Computed conditional probabilities for sample 184000 / 255858
# [t-SNE] Computed conditional probabilities for sample 185000 / 255858
# [t-SNE] Computed conditional probabilities for sample 186000 / 255858
# [t-SNE] Computed conditional probabilities for sample 187000 / 255858
# [t-SNE] Computed conditional probabilities for sample 188000 / 255858
# [t-SNE] Computed conditional probabilities for sample 189000 / 255858
# [t-SNE] Computed conditional probabilities for sample 190000 / 255858
# [t-SNE] Computed conditional probabilities for sample 191000 / 255858
# [t-SNE] Computed conditional probabilities for sample 192000 / 255858
# [t-SNE] Computed conditional probabilities for sample 193000 / 255858
# [t-SNE] Computed conditional probabilities for sample 194000 / 255858
# [t-SNE] Computed conditional probabilities for sample 195000 / 255858
# [t-SNE] Computed conditional probabilities for sample 196000 / 255858
# [t-SNE] Computed conditional probabilities for sample 197000 / 255858
# [t-SNE] Computed conditional probabilities for sample 198000 / 255858
# [t-SNE] Computed conditional probabilities for sample 199000 / 255858
# [t-SNE] Computed conditional probabilities for sample 200000 / 255858
# [t-SNE] Computed conditional probabilities for sample 201000 / 255858
# [t-SNE] Computed conditional probabilities for sample 202000 / 255858
# [t-SNE] Computed conditional probabilities for sample 203000 / 255858
# [t-SNE] Computed conditional probabilities for sample 204000 / 255858
# [t-SNE] Computed conditional probabilities for sample 205000 / 255858
# [t-SNE] Computed conditional probabilities for sample 206000 / 255858
# [t-SNE] Computed conditional probabilities for sample 207000 / 255858
# [t-SNE] Computed conditional probabilities for sample 208000 / 255858
# [t-SNE] Computed conditional probabilities for sample 209000 / 255858
# [t-SNE] Computed conditional probabilities for sample 210000 / 255858
# [t-SNE] Computed conditional probabilities for sample 211000 / 255858
# [t-SNE] Computed conditional probabilities for sample 212000 / 255858
# [t-SNE] Computed conditional probabilities for sample 213000 / 255858
# [t-SNE] Computed conditional probabilities for sample 214000 / 255858
# [t-SNE] Computed conditional probabilities for sample 215000 / 255858
# [t-SNE] Computed conditional probabilities for sample 216000 / 255858
# [t-SNE] Computed conditional probabilities for sample 217000 / 255858
# [t-SNE] Computed conditional probabilities for sample 218000 / 255858
# [t-SNE] Computed conditional probabilities for sample 219000 / 255858
# [t-SNE] Computed conditional probabilities for sample 220000 / 255858
# [t-SNE] Computed conditional probabilities for sample 221000 / 255858
# [t-SNE] Computed conditional probabilities for sample 222000 / 255858
# [t-SNE] Computed conditional probabilities for sample 223000 / 255858
# [t-SNE] Computed conditional probabilities for sample 224000 / 255858
# [t-SNE] Computed conditional probabilities for sample 225000 / 255858
# [t-SNE] Computed conditional probabilities for sample 226000 / 255858
# [t-SNE] Computed conditional probabilities for sample 227000 / 255858
# [t-SNE] Computed conditional probabilities for sample 228000 / 255858
# [t-SNE] Computed conditional probabilities for sample 229000 / 255858
# [t-SNE] Computed conditional probabilities for sample 230000 / 255858
# [t-SNE] Computed conditional probabilities for sample 231000 / 255858
# [t-SNE] Computed conditional probabilities for sample 232000 / 255858
# [t-SNE] Computed conditional probabilities for sample 233000 / 255858
# [t-SNE] Computed conditional probabilities for sample 234000 / 255858
# [t-SNE] Computed conditional probabilities for sample 235000 / 255858
# [t-SNE] Computed conditional probabilities for sample 236000 / 255858
# [t-SNE] Computed conditional probabilities for sample 237000 / 255858
# [t-SNE] Computed conditional probabilities for sample 238000 / 255858
# [t-SNE] Computed conditional probabilities for sample 239000 / 255858
# [t-SNE] Computed conditional probabilities for sample 240000 / 255858
# [t-SNE] Computed conditional probabilities for sample 241000 / 255858
# [t-SNE] Computed conditional probabilities for sample 242000 / 255858
# [t-SNE] Computed conditional probabilities for sample 243000 / 255858
# [t-SNE] Computed conditional probabilities for sample 244000 / 255858
# [t-SNE] Computed conditional probabilities for sample 245000 / 255858
# [t-SNE] Computed conditional probabilities for sample 246000 / 255858
# [t-SNE] Computed conditional probabilities for sample 247000 / 255858
# [t-SNE] Computed conditional probabilities for sample 248000 / 255858
# [t-SNE] Computed conditional probabilities for sample 249000 / 255858
# [t-SNE] Computed conditional probabilities for sample 250000 / 255858
# [t-SNE] Computed conditional probabilities for sample 251000 / 255858
# [t-SNE] Computed conditional probabilities for sample 252000 / 255858
# [t-SNE] Computed conditional probabilities for sample 253000 / 255858
# [t-SNE] Computed conditional probabilities for sample 254000 / 255858
# [t-SNE] Computed conditional probabilities for sample 255000 / 255858
# [t-SNE] Computed conditional probabilities for sample 255858 / 255858
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Computed conditional probabilities in 2.852s
# [t-SNE] Iteration 50: error = 165.8772278, gradient norm = 0.0000009 (50 iterations in 236.022s)
# [t-SNE] Iteration 100: error = 165.8768616, gradient norm = 0.0000355 (50 iterations in 243.996s)
# [t-SNE] Iteration 150: error = 160.9658203, gradient norm = 0.0017068 (50 iterations in 246.826s)
# [t-SNE] Iteration 200: error = 146.8485107, gradient norm = 0.0009634 (50 iterations in 200.745s)
# [t-SNE] Iteration 250: error = 140.0602417, gradient norm = 0.0007374 (50 iterations in 192.323s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 140.060242
# [t-SNE] Iteration 300: error = 9.0510654, gradient norm = 0.0007251 (50 iterations in 192.948s)
# [t-SNE] Iteration 350: error = 8.7085266, gradient norm = 0.0005940 (50 iterations in 188.596s)
# [t-SNE] Iteration 400: error = 8.3796387, gradient norm = 0.0004794 (50 iterations in 176.030s)
# [t-SNE] Iteration 450: error = 8.0563831, gradient norm = 0.0003937 (50 iterations in 175.056s)
# [t-SNE] Iteration 500: error = 7.7247758, gradient norm = 0.0003310 (50 iterations in 180.134s)
# [t-SNE] Iteration 550: error = 7.4678125, gradient norm = 0.0002843 (50 iterations in 175.751s)
# [t-SNE] Iteration 600: error = 7.2543917, gradient norm = 0.0002486 (50 iterations in 173.555s)
# [t-SNE] Iteration 650: error = 7.0045166, gradient norm = 0.0002206 (50 iterations in 169.689s)
# [t-SNE] Iteration 700: error = 6.8330021, gradient norm = 0.0001981 (50 iterations in 166.698s)
# [t-SNE] Iteration 750: error = 6.6599464, gradient norm = 0.0001797 (50 iterations in 165.693s)
# [t-SNE] Iteration 800: error = 6.5143099, gradient norm = 0.0001643 (50 iterations in 163.740s)
# [t-SNE] Iteration 850: error = 6.3810892, gradient norm = 0.0001513 (50 iterations in 160.823s)
# [t-SNE] Iteration 900: error = 6.2026024, gradient norm = 0.0001402 (50 iterations in 170.252s)
# [t-SNE] Iteration 950: error = 6.0868363, gradient norm = 0.0001306 (50 iterations in 172.996s)
# [t-SNE] Iteration 1000: error = 5.9782267, gradient norm = 0.0001222 (50 iterations in 164.824s)
# [t-SNE] KL divergence after 1000 iterations: 5.978227
# Done..
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.8/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 5 and with 1000 iterations at max
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 255858 samples in 0.325s...
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computed neighbors for 255858 samples in 4.183s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 255858
# [t-SNE] Computed conditional probabilities for sample 2000 / 255858
# [t-SNE] Computed conditional probabilities for sample 3000 / 255858
# [t-SNE] Computed conditional probabilities for sample 4000 / 255858
# [t-SNE] Computed conditional probabilities for sample 5000 / 255858
# [t-SNE] Computed conditional probabilities for sample 6000 / 255858
# [t-SNE] Computed conditional probabilities for sample 7000 / 255858
# [t-SNE] Computed conditional probabilities for sample 8000 / 255858
# [t-SNE] Computed conditional probabilities for sample 9000 / 255858
# [t-SNE] Computed conditional probabilities for sample 10000 / 255858
# [t-SNE] Computed conditional probabilities for sample 11000 / 255858
# [t-SNE] Computed conditional probabilities for sample 12000 / 255858
# [t-SNE] Computed conditional probabilities for sample 13000 / 255858
# [t-SNE] Computed conditional probabilities for sample 14000 / 255858
# [t-SNE] Computed conditional probabilities for sample 15000 / 255858
# [t-SNE] Computed conditional probabilities for sample 16000 / 255858
# [t-SNE] Computed conditional probabilities for sample 17000 / 255858
# [t-SNE] Computed conditional probabilities for sample 18000 / 255858
# [t-SNE] Computed conditional probabilities for sample 19000 / 255858
# [t-SNE] Computed conditional probabilities for sample 20000 / 255858
# [t-SNE] Computed conditional probabilities for sample 21000 / 255858
# [t-SNE] Computed conditional probabilities for sample 22000 / 255858
# [t-SNE] Computed conditional probabilities for sample 23000 / 255858
# [t-SNE] Computed conditional probabilities for sample 24000 / 255858
# [t-SNE] Computed conditional probabilities for sample 25000 / 255858
# [t-SNE] Computed conditional probabilities for sample 26000 / 255858
# [t-SNE] Computed conditional probabilities for sample 27000 / 255858
# [t-SNE] Computed conditional probabilities for sample 28000 / 255858
# [t-SNE] Computed conditional probabilities for sample 29000 / 255858
# [t-SNE] Computed conditional probabilities for sample 30000 / 255858
# [t-SNE] Computed conditional probabilities for sample 31000 / 255858
# [t-SNE] Computed conditional probabilities for sample 32000 / 255858
# [t-SNE] Computed conditional probabilities for sample 33000 / 255858
# [t-SNE] Computed conditional probabilities for sample 34000 / 255858
# [t-SNE] Computed conditional probabilities for sample 35000 / 255858
# [t-SNE] Computed conditional probabilities for sample 36000 / 255858
# [t-SNE] Computed conditional probabilities for sample 37000 / 255858
# [t-SNE] Computed conditional probabilities for sample 38000 / 255858
# [t-SNE] Computed conditional probabilities for sample 39000 / 255858
# [t-SNE] Computed conditional probabilities for sample 40000 / 255858
# [t-SNE] Computed conditional probabilities for sample 41000 / 255858
# [t-SNE] Computed conditional probabilities for sample 42000 / 255858
# [t-SNE] Computed conditional probabilities for sample 43000 / 255858
# [t-SNE] Computed conditional probabilities for sample 44000 / 255858
# [t-SNE] Computed conditional probabilities for sample 45000 / 255858
# [t-SNE] Computed conditional probabilities for sample 46000 / 255858
# [t-SNE] Computed conditional probabilities for sample 47000 / 255858
# [t-SNE] Computed conditional probabilities for sample 48000 / 255858
# [t-SNE] Computed conditional probabilities for sample 49000 / 255858
# [t-SNE] Computed conditional probabilities for sample 50000 / 255858
# [t-SNE] Computed conditional probabilities for sample 51000 / 255858
# [t-SNE] Computed conditional probabilities for sample 52000 / 255858
# [t-SNE] Computed conditional probabilities for sample 53000 / 255858
# [t-SNE] Computed conditional probabilities for sample 54000 / 255858
# [t-SNE] Computed conditional probabilities for sample 55000 / 255858
# [t-SNE] Computed conditional probabilities for sample 56000 / 255858
# [t-SNE] Computed conditional probabilities for sample 57000 / 255858
# [t-SNE] Computed conditional probabilities for sample 58000 / 255858
# [t-SNE] Computed conditional probabilities for sample 59000 / 255858
# [t-SNE] Computed conditional probabilities for sample 60000 / 255858
# [t-SNE] Computed conditional probabilities for sample 61000 / 255858
# [t-SNE] Computed conditional probabilities for sample 62000 / 255858
# [t-SNE] Computed conditional probabilities for sample 63000 / 255858
# [t-SNE] Computed conditional probabilities for sample 64000 / 255858
# [t-SNE] Computed conditional probabilities for sample 65000 / 255858
# [t-SNE] Computed conditional probabilities for sample 66000 / 255858
# [t-SNE] Computed conditional probabilities for sample 67000 / 255858
# [t-SNE] Computed conditional probabilities for sample 68000 / 255858
# [t-SNE] Computed conditional probabilities for sample 69000 / 255858
# [t-SNE] Computed conditional probabilities for sample 70000 / 255858
# [t-SNE] Computed conditional probabilities for sample 71000 / 255858
# [t-SNE] Computed conditional probabilities for sample 72000 / 255858
# [t-SNE] Computed conditional probabilities for sample 73000 / 255858
# [t-SNE] Computed conditional probabilities for sample 74000 / 255858
# [t-SNE] Computed conditional probabilities for sample 75000 / 255858
# [t-SNE] Computed conditional probabilities for sample 76000 / 255858
# [t-SNE] Computed conditional probabilities for sample 77000 / 255858
# [t-SNE] Computed conditional probabilities for sample 78000 / 255858
# [t-SNE] Computed conditional probabilities for sample 79000 / 255858
# [t-SNE] Computed conditional probabilities for sample 80000 / 255858
# [t-SNE] Computed conditional probabilities for sample 81000 / 255858
# [t-SNE] Computed conditional probabilities for sample 82000 / 255858
# [t-SNE] Computed conditional probabilities for sample 83000 / 255858
# [t-SNE] Computed conditional probabilities for sample 84000 / 255858
# [t-SNE] Computed conditional probabilities for sample 85000 / 255858
# [t-SNE] Computed conditional probabilities for sample 86000 / 255858
# [t-SNE] Computed conditional probabilities for sample 87000 / 255858
# [t-SNE] Computed conditional probabilities for sample 88000 / 255858
# [t-SNE] Computed conditional probabilities for sample 89000 / 255858
# [t-SNE] Computed conditional probabilities for sample 90000 / 255858
# [t-SNE] Computed conditional probabilities for sample 91000 / 255858
# [t-SNE] Computed conditional probabilities for sample 92000 / 255858
# [t-SNE] Computed conditional probabilities for sample 93000 / 255858
# [t-SNE] Computed conditional probabilities for sample 94000 / 255858
# [t-SNE] Computed conditional probabilities for sample 95000 / 255858
# [t-SNE] Computed conditional probabilities for sample 96000 / 255858
# [t-SNE] Computed conditional probabilities for sample 97000 / 255858
# [t-SNE] Computed conditional probabilities for sample 98000 / 255858
# [t-SNE] Computed conditional probabilities for sample 99000 / 255858
# [t-SNE] Computed conditional probabilities for sample 100000 / 255858
# [t-SNE] Computed conditional probabilities for sample 101000 / 255858
# [t-SNE] Computed conditional probabilities for sample 102000 / 255858
# [t-SNE] Computed conditional probabilities for sample 103000 / 255858
# [t-SNE] Computed conditional probabilities for sample 104000 / 255858
# [t-SNE] Computed conditional probabilities for sample 105000 / 255858
# [t-SNE] Computed conditional probabilities for sample 106000 / 255858
# [t-SNE] Computed conditional probabilities for sample 107000 / 255858
# [t-SNE] Computed conditional probabilities for sample 108000 / 255858
# [t-SNE] Computed conditional probabilities for sample 109000 / 255858
# [t-SNE] Computed conditional probabilities for sample 110000 / 255858
# [t-SNE] Computed conditional probabilities for sample 111000 / 255858
# [t-SNE] Computed conditional probabilities for sample 112000 / 255858
# [t-SNE] Computed conditional probabilities for sample 113000 / 255858
# [t-SNE] Computed conditional probabilities for sample 114000 / 255858
# [t-SNE] Computed conditional probabilities for sample 115000 / 255858
# [t-SNE] Computed conditional probabilities for sample 116000 / 255858
# [t-SNE] Computed conditional probabilities for sample 117000 / 255858
# [t-SNE] Computed conditional probabilities for sample 118000 / 255858
# [t-SNE] Computed conditional probabilities for sample 119000 / 255858
# [t-SNE] Computed conditional probabilities for sample 120000 / 255858
# [t-SNE] Computed conditional probabilities for sample 121000 / 255858
# [t-SNE] Computed conditional probabilities for sample 122000 / 255858
# [t-SNE] Computed conditional probabilities for sample 123000 / 255858
# [t-SNE] Computed conditional probabilities for sample 124000 / 255858
# [t-SNE] Computed conditional probabilities for sample 125000 / 255858
# [t-SNE] Computed conditional probabilities for sample 126000 / 255858
# [t-SNE] Computed conditional probabilities for sample 127000 / 255858
# [t-SNE] Computed conditional probabilities for sample 128000 / 255858
# [t-SNE] Computed conditional probabilities for sample 129000 / 255858
# [t-SNE] Computed conditional probabilities for sample 130000 / 255858
# [t-SNE] Computed conditional probabilities for sample 131000 / 255858
# [t-SNE] Computed conditional probabilities for sample 132000 / 255858
# [t-SNE] Computed conditional probabilities for sample 133000 / 255858
# [t-SNE] Computed conditional probabilities for sample 134000 / 255858
# [t-SNE] Computed conditional probabilities for sample 135000 / 255858
# [t-SNE] Computed conditional probabilities for sample 136000 / 255858
# [t-SNE] Computed conditional probabilities for sample 137000 / 255858
# [t-SNE] Computed conditional probabilities for sample 138000 / 255858
# [t-SNE] Computed conditional probabilities for sample 139000 / 255858
# [t-SNE] Computed conditional probabilities for sample 140000 / 255858
# [t-SNE] Computed conditional probabilities for sample 141000 / 255858
# [t-SNE] Computed conditional probabilities for sample 142000 / 255858
# [t-SNE] Computed conditional probabilities for sample 143000 / 255858
# [t-SNE] Computed conditional probabilities for sample 144000 / 255858
# [t-SNE] Computed conditional probabilities for sample 145000 / 255858
# [t-SNE] Computed conditional probabilities for sample 146000 / 255858
# [t-SNE] Computed conditional probabilities for sample 147000 / 255858
# [t-SNE] Computed conditional probabilities for sample 148000 / 255858
# [t-SNE] Computed conditional probabilities for sample 149000 / 255858
# [t-SNE] Computed conditional probabilities for sample 150000 / 255858
# [t-SNE] Computed conditional probabilities for sample 151000 / 255858
# [t-SNE] Computed conditional probabilities for sample 152000 / 255858
# [t-SNE] Computed conditional probabilities for sample 153000 / 255858
# [t-SNE] Computed conditional probabilities for sample 154000 / 255858
# [t-SNE] Computed conditional probabilities for sample 155000 / 255858
# [t-SNE] Computed conditional probabilities for sample 156000 / 255858
# [t-SNE] Computed conditional probabilities for sample 157000 / 255858
# [t-SNE] Computed conditional probabilities for sample 158000 / 255858
# [t-SNE] Computed conditional probabilities for sample 159000 / 255858
# [t-SNE] Computed conditional probabilities for sample 160000 / 255858
# [t-SNE] Computed conditional probabilities for sample 161000 / 255858
# [t-SNE] Computed conditional probabilities for sample 162000 / 255858
# [t-SNE] Computed conditional probabilities for sample 163000 / 255858
# [t-SNE] Computed conditional probabilities for sample 164000 / 255858
# [t-SNE] Computed conditional probabilities for sample 165000 / 255858
# [t-SNE] Computed conditional probabilities for sample 166000 / 255858
# [t-SNE] Computed conditional probabilities for sample 167000 / 255858
# [t-SNE] Computed conditional probabilities for sample 168000 / 255858
# [t-SNE] Computed conditional probabilities for sample 169000 / 255858
# [t-SNE] Computed conditional probabilities for sample 170000 / 255858
# [t-SNE] Computed conditional probabilities for sample 171000 / 255858
# [t-SNE] Computed conditional probabilities for sample 172000 / 255858
# [t-SNE] Computed conditional probabilities for sample 173000 / 255858
# [t-SNE] Computed conditional probabilities for sample 174000 / 255858
# [t-SNE] Computed conditional probabilities for sample 175000 / 255858
# [t-SNE] Computed conditional probabilities for sample 176000 / 255858
# [t-SNE] Computed conditional probabilities for sample 177000 / 255858
# [t-SNE] Computed conditional probabilities for sample 178000 / 255858
# [t-SNE] Computed conditional probabilities for sample 179000 / 255858
# [t-SNE] Computed conditional probabilities for sample 180000 / 255858
# [t-SNE] Computed conditional probabilities for sample 181000 / 255858
# [t-SNE] Computed conditional probabilities for sample 182000 / 255858
# [t-SNE] Computed conditional probabilities for sample 183000 / 255858
# [t-SNE] Computed conditional probabilities for sample 184000 / 255858
# [t-SNE] Computed conditional probabilities for sample 185000 / 255858
# [t-SNE] Computed conditional probabilities for sample 186000 / 255858
# [t-SNE] Computed conditional probabilities for sample 187000 / 255858
# [t-SNE] Computed conditional probabilities for sample 188000 / 255858
# [t-SNE] Computed conditional probabilities for sample 189000 / 255858
# [t-SNE] Computed conditional probabilities for sample 190000 / 255858
# [t-SNE] Computed conditional probabilities for sample 191000 / 255858
# [t-SNE] Computed conditional probabilities for sample 192000 / 255858
# [t-SNE] Computed conditional probabilities for sample 193000 / 255858
# [t-SNE] Computed conditional probabilities for sample 194000 / 255858
# [t-SNE] Computed conditional probabilities for sample 195000 / 255858
# [t-SNE] Computed conditional probabilities for sample 196000 / 255858
# [t-SNE] Computed conditional probabilities for sample 197000 / 255858
# [t-SNE] Computed conditional probabilities for sample 198000 / 255858
# [t-SNE] Computed conditional probabilities for sample 199000 / 255858
# [t-SNE] Computed conditional probabilities for sample 200000 / 255858
# [t-SNE] Computed conditional probabilities for sample 201000 / 255858
# [t-SNE] Computed conditional probabilities for sample 202000 / 255858
# [t-SNE] Computed conditional probabilities for sample 203000 / 255858
# [t-SNE] Computed conditional probabilities for sample 204000 / 255858
# [t-SNE] Computed conditional probabilities for sample 205000 / 255858
# [t-SNE] Computed conditional probabilities for sample 206000 / 255858
# [t-SNE] Computed conditional probabilities for sample 207000 / 255858
# [t-SNE] Computed conditional probabilities for sample 208000 / 255858
# [t-SNE] Computed conditional probabilities for sample 209000 / 255858
# [t-SNE] Computed conditional probabilities for sample 210000 / 255858
# [t-SNE] Computed conditional probabilities for sample 211000 / 255858
# [t-SNE] Computed conditional probabilities for sample 212000 / 255858
# [t-SNE] Computed conditional probabilities for sample 213000 / 255858
# [t-SNE] Computed conditional probabilities for sample 214000 / 255858
# [t-SNE] Computed conditional probabilities for sample 215000 / 255858
# [t-SNE] Computed conditional probabilities for sample 216000 / 255858
# [t-SNE] Computed conditional probabilities for sample 217000 / 255858
# [t-SNE] Computed conditional probabilities for sample 218000 / 255858
# [t-SNE] Computed conditional probabilities for sample 219000 / 255858
# [t-SNE] Computed conditional probabilities for sample 220000 / 255858
# [t-SNE] Computed conditional probabilities for sample 221000 / 255858
# [t-SNE] Computed conditional probabilities for sample 222000 / 255858
# [t-SNE] Computed conditional probabilities for sample 223000 / 255858
# [t-SNE] Computed conditional probabilities for sample 224000 / 255858
# [t-SNE] Computed conditional probabilities for sample 225000 / 255858
# [t-SNE] Computed conditional probabilities for sample 226000 / 255858
# [t-SNE] Computed conditional probabilities for sample 227000 / 255858
# [t-SNE] Computed conditional probabilities for sample 228000 / 255858
# [t-SNE] Computed conditional probabilities for sample 229000 / 255858
# [t-SNE] Computed conditional probabilities for sample 230000 / 255858
# [t-SNE] Computed conditional probabilities for sample 231000 / 255858
# [t-SNE] Computed conditional probabilities for sample 232000 / 255858
# [t-SNE] Computed conditional probabilities for sample 233000 / 255858
# [t-SNE] Computed conditional probabilities for sample 234000 / 255858
# [t-SNE] Computed conditional probabilities for sample 235000 / 255858
# [t-SNE] Computed conditional probabilities for sample 236000 / 255858
# [t-SNE] Computed conditional probabilities for sample 237000 / 255858
# [t-SNE] Computed conditional probabilities for sample 238000 / 255858
# [t-SNE] Computed conditional probabilities for sample 239000 / 255858
# [t-SNE] Computed conditional probabilities for sample 240000 / 255858
# [t-SNE] Computed conditional probabilities for sample 241000 / 255858
# [t-SNE] Computed conditional probabilities for sample 242000 / 255858
# [t-SNE] Computed conditional probabilities for sample 243000 / 255858
# [t-SNE] Computed conditional probabilities for sample 244000 / 255858
# [t-SNE] Computed conditional probabilities for sample 245000 / 255858
# [t-SNE] Computed conditional probabilities for sample 246000 / 255858
# [t-SNE] Computed conditional probabilities for sample 247000 / 255858
# [t-SNE] Computed conditional probabilities for sample 248000 / 255858
# [t-SNE] Computed conditional probabilities for sample 249000 / 255858
# [t-SNE] Computed conditional probabilities for sample 250000 / 255858
# [t-SNE] Computed conditional probabilities for sample 251000 / 255858
# [t-SNE] Computed conditional probabilities for sample 252000 / 255858
# [t-SNE] Computed conditional probabilities for sample 253000 / 255858
# [t-SNE] Computed conditional probabilities for sample 254000 / 255858
# [t-SNE] Computed conditional probabilities for sample 255000 / 255858
# [t-SNE] Computed conditional probabilities for sample 255858 / 255858
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Computed conditional probabilities in 4.130s
# [t-SNE] Iteration 50: error = 156.2577209, gradient norm = 0.0000004 (50 iterations in 247.650s)
# [t-SNE] Iteration 100: error = 156.2576447, gradient norm = 0.0000165 (50 iterations in 270.258s)
# [t-SNE] Iteration 150: error = 154.2108307, gradient norm = 0.0013768 (50 iterations in 272.547s)
# [t-SNE] Iteration 200: error = 138.9600067, gradient norm = 0.0009702 (50 iterations in 210.987s)
# [t-SNE] Iteration 250: error = 132.2940979, gradient norm = 0.0007152 (50 iterations in 207.509s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 132.294098
# [t-SNE] Iteration 300: error = 8.3480043, gradient norm = 0.0007566 (50 iterations in 203.571s)
# [t-SNE] Iteration 350: error = 7.9879413, gradient norm = 0.0006074 (50 iterations in 197.053s)
# [t-SNE] Iteration 400: error = 7.6404366, gradient norm = 0.0004834 (50 iterations in 194.601s)
# [t-SNE] Iteration 450: error = 7.2936087, gradient norm = 0.0003939 (50 iterations in 190.950s)
# [t-SNE] Iteration 500: error = 7.0127425, gradient norm = 0.0003300 (50 iterations in 192.335s)
# [t-SNE] Iteration 550: error = 6.7601461, gradient norm = 0.0002831 (50 iterations in 191.560s)
# [t-SNE] Iteration 600: error = 6.4988303, gradient norm = 0.0002476 (50 iterations in 194.457s)
# [t-SNE] Iteration 650: error = 6.2694740, gradient norm = 0.0002198 (50 iterations in 196.104s)
# [t-SNE] Iteration 700: error = 6.0963192, gradient norm = 0.0001974 (50 iterations in 189.841s)
# [t-SNE] Iteration 750: error = 5.9320040, gradient norm = 0.0001791 (50 iterations in 186.439s)
# [t-SNE] Iteration 800: error = 5.7877636, gradient norm = 0.0001637 (50 iterations in 183.915s)
# [t-SNE] Iteration 850: error = 5.6486816, gradient norm = 0.0001506 (50 iterations in 181.519s)
# [t-SNE] Iteration 900: error = 5.5228977, gradient norm = 0.0001395 (50 iterations in 182.950s)
# [t-SNE] Iteration 950: error = 5.3869066, gradient norm = 0.0001298 (50 iterations in 181.097s)
# [t-SNE] Iteration 1000: error = 5.2822866, gradient norm = 0.0001214 (50 iterations in 179.900s)
# [t-SNE] KL divergence after 1000 iterations: 5.282287
# Done..
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.8/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done
#
# performing tsne with perplexity 10 and with 1000 iterations at max
# [t-SNE] Computing 31 nearest neighbors...
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/manifold/_t_sne.py:790: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Indexed 255858 samples in 0.313s...
# [t-SNE] Computed neighbors for 255858 samples in 5.976s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 255858
# [t-SNE] Computed conditional probabilities for sample 2000 / 255858
# [t-SNE] Computed conditional probabilities for sample 3000 / 255858
# [t-SNE] Computed conditional probabilities for sample 4000 / 255858
# [t-SNE] Computed conditional probabilities for sample 5000 / 255858
# [t-SNE] Computed conditional probabilities for sample 6000 / 255858
# [t-SNE] Computed conditional probabilities for sample 7000 / 255858
# [t-SNE] Computed conditional probabilities for sample 8000 / 255858
# [t-SNE] Computed conditional probabilities for sample 9000 / 255858
# [t-SNE] Computed conditional probabilities for sample 10000 / 255858
# [t-SNE] Computed conditional probabilities for sample 11000 / 255858
# [t-SNE] Computed conditional probabilities for sample 12000 / 255858
# [t-SNE] Computed conditional probabilities for sample 13000 / 255858
# [t-SNE] Computed conditional probabilities for sample 14000 / 255858
# [t-SNE] Computed conditional probabilities for sample 15000 / 255858
# [t-SNE] Computed conditional probabilities for sample 16000 / 255858
# [t-SNE] Computed conditional probabilities for sample 17000 / 255858
# [t-SNE] Computed conditional probabilities for sample 18000 / 255858
# [t-SNE] Computed conditional probabilities for sample 19000 / 255858
# [t-SNE] Computed conditional probabilities for sample 20000 / 255858
# [t-SNE] Computed conditional probabilities for sample 21000 / 255858
# [t-SNE] Computed conditional probabilities for sample 22000 / 255858
# [t-SNE] Computed conditional probabilities for sample 23000 / 255858
# [t-SNE] Computed conditional probabilities for sample 24000 / 255858
# [t-SNE] Computed conditional probabilities for sample 25000 / 255858
# [t-SNE] Computed conditional probabilities for sample 26000 / 255858
# [t-SNE] Computed conditional probabilities for sample 27000 / 255858
# [t-SNE] Computed conditional probabilities for sample 28000 / 255858
# [t-SNE] Computed conditional probabilities for sample 29000 / 255858
# [t-SNE] Computed conditional probabilities for sample 30000 / 255858
# [t-SNE] Computed conditional probabilities for sample 31000 / 255858
# [t-SNE] Computed conditional probabilities for sample 32000 / 255858
# [t-SNE] Computed conditional probabilities for sample 33000 / 255858
# [t-SNE] Computed conditional probabilities for sample 34000 / 255858
# [t-SNE] Computed conditional probabilities for sample 35000 / 255858
# [t-SNE] Computed conditional probabilities for sample 36000 / 255858
# [t-SNE] Computed conditional probabilities for sample 37000 / 255858
# [t-SNE] Computed conditional probabilities for sample 38000 / 255858
# [t-SNE] Computed conditional probabilities for sample 39000 / 255858
# [t-SNE] Computed conditional probabilities for sample 40000 / 255858
# [t-SNE] Computed conditional probabilities for sample 41000 / 255858
# [t-SNE] Computed conditional probabilities for sample 42000 / 255858
# [t-SNE] Computed conditional probabilities for sample 43000 / 255858
# [t-SNE] Computed conditional probabilities for sample 44000 / 255858
# [t-SNE] Computed conditional probabilities for sample 45000 / 255858
# [t-SNE] Computed conditional probabilities for sample 46000 / 255858
# [t-SNE] Computed conditional probabilities for sample 47000 / 255858
# [t-SNE] Computed conditional probabilities for sample 48000 / 255858
# [t-SNE] Computed conditional probabilities for sample 49000 / 255858
# [t-SNE] Computed conditional probabilities for sample 50000 / 255858
# [t-SNE] Computed conditional probabilities for sample 51000 / 255858
# [t-SNE] Computed conditional probabilities for sample 52000 / 255858
# [t-SNE] Computed conditional probabilities for sample 53000 / 255858
# [t-SNE] Computed conditional probabilities for sample 54000 / 255858
# [t-SNE] Computed conditional probabilities for sample 55000 / 255858
# [t-SNE] Computed conditional probabilities for sample 56000 / 255858
# [t-SNE] Computed conditional probabilities for sample 57000 / 255858
# [t-SNE] Computed conditional probabilities for sample 58000 / 255858
# [t-SNE] Computed conditional probabilities for sample 59000 / 255858
# [t-SNE] Computed conditional probabilities for sample 60000 / 255858
# [t-SNE] Computed conditional probabilities for sample 61000 / 255858
# [t-SNE] Computed conditional probabilities for sample 62000 / 255858
# [t-SNE] Computed conditional probabilities for sample 63000 / 255858
# [t-SNE] Computed conditional probabilities for sample 64000 / 255858
# [t-SNE] Computed conditional probabilities for sample 65000 / 255858
# [t-SNE] Computed conditional probabilities for sample 66000 / 255858
# [t-SNE] Computed conditional probabilities for sample 67000 / 255858
# [t-SNE] Computed conditional probabilities for sample 68000 / 255858
# [t-SNE] Computed conditional probabilities for sample 69000 / 255858
# [t-SNE] Computed conditional probabilities for sample 70000 / 255858
# [t-SNE] Computed conditional probabilities for sample 71000 / 255858
# [t-SNE] Computed conditional probabilities for sample 72000 / 255858
# [t-SNE] Computed conditional probabilities for sample 73000 / 255858
# [t-SNE] Computed conditional probabilities for sample 74000 / 255858
# [t-SNE] Computed conditional probabilities for sample 75000 / 255858
# [t-SNE] Computed conditional probabilities for sample 76000 / 255858
# [t-SNE] Computed conditional probabilities for sample 77000 / 255858
# [t-SNE] Computed conditional probabilities for sample 78000 / 255858
# [t-SNE] Computed conditional probabilities for sample 79000 / 255858
# [t-SNE] Computed conditional probabilities for sample 80000 / 255858
# [t-SNE] Computed conditional probabilities for sample 81000 / 255858
# [t-SNE] Computed conditional probabilities for sample 82000 / 255858
# [t-SNE] Computed conditional probabilities for sample 83000 / 255858
# ...
# [t-SNE] Computed conditional probabilities for sample 63000 / 255858
# [t-SNE] Computed conditional probabilities for sample 64000 / 255858
# [t-SNE] Computed conditional probabilities for sample 65000 / 255858
# [t-SNE] Computed conditional probabilities for sample 66000 / 255858
# [t-SNE] Computed conditional probabilities for sample 67000 / 255858
# [t-SNE] Computed conditional probabilities for sample 68000 / 255858
# [t-SNE] Computed conditional probabilities for sample 69000 / 255858
# [t-SNE] Computed conditional probabilities for sample 70000 / 255858
# [t-SNE] Computed conditional probabilities for sample 71000 / 255858
# [t-SNE] Computed conditional probabilities for sample 72000 / 255858
# [t-SNE] Computed conditional probabilities for sample 73000 / 255858
# [t-SNE] Computed conditional probabilities for sample 74000 / 255858
# [t-SNE] Computed conditional probabilities for sample 75000 / 255858
# [t-SNE] Computed conditional probabilities for sample 76000 / 255858
# [t-SNE] Computed conditional probabilities for sample 77000 / 255858
# [t-SNE] Computed conditional probabilities for sample 78000 / 255858
# [t-SNE] Computed conditional probabilities for sample 79000 / 255858
# [t-SNE] Computed conditional probabilities for sample 80000 / 255858
# [t-SNE] Computed conditional probabilities for sample 81000 / 255858
# [t-SNE] Computed conditional probabilities for sample 82000 / 255858
# [t-SNE] Computed conditional probabilities for sample 83000 / 255858
# [t-SNE] Computed conditional probabilities for sample 84000 / 255858
# [t-SNE] Computed conditional probabilities for sample 85000 / 255858
# [t-SNE] Computed conditional probabilities for sample 86000 / 255858
# [t-SNE] Computed conditional probabilities for sample 87000 / 255858
# [t-SNE] Computed conditional probabilities for sample 88000 / 255858
# [t-SNE] Computed conditional probabilities for sample 89000 / 255858
# [t-SNE] Computed conditional probabilities for sample 90000 / 255858
# [t-SNE] Computed conditional probabilities for sample 91000 / 255858
# [t-SNE] Computed conditional probabilities for sample 92000 / 255858
# [t-SNE] Computed conditional probabilities for sample 93000 / 255858
# [t-SNE] Computed conditional probabilities for sample 94000 / 255858
# [t-SNE] Computed conditional probabilities for sample 95000 / 255858
# [t-SNE] Computed conditional probabilities for sample 96000 / 255858
# [t-SNE] Computed conditional probabilities for sample 97000 / 255858
# [t-SNE] Computed conditional probabilities for sample 98000 / 255858
# [t-SNE] Computed conditional probabilities for sample 99000 / 255858
# [t-SNE] Computed conditional probabilities for sample 100000 / 255858
# [t-SNE] Computed conditional probabilities for sample 101000 / 255858
# [t-SNE] Computed conditional probabilities for sample 102000 / 255858
# [t-SNE] Computed conditional probabilities for sample 103000 / 255858
# [t-SNE] Computed conditional probabilities for sample 104000 / 255858
# [t-SNE] Computed conditional probabilities for sample 105000 / 255858
# [t-SNE] Computed conditional probabilities for sample 106000 / 255858
# [t-SNE] Computed conditional probabilities for sample 107000 / 255858
# [t-SNE] Computed conditional probabilities for sample 108000 / 255858
# [t-SNE] Computed conditional probabilities for sample 109000 / 255858
# [t-SNE] Computed conditional probabilities for sample 110000 / 255858
# [t-SNE] Computed conditional probabilities for sample 111000 / 255858
# [t-SNE] Computed conditional probabilities for sample 112000 / 255858
# [t-SNE] Computed conditional probabilities for sample 113000 / 255858
# [t-SNE] Computed conditional probabilities for sample 114000 / 255858
# [t-SNE] Computed conditional probabilities for sample 115000 / 255858
# [t-SNE] Computed conditional probabilities for sample 116000 / 255858
# [t-SNE] Computed conditional probabilities for sample 117000 / 255858
# [t-SNE] Computed conditional probabilities for sample 118000 / 255858
# [t-SNE] Computed conditional probabilities for sample 119000 / 255858
# [t-SNE] Computed conditional probabilities for sample 120000 / 255858
# [t-SNE] Computed conditional probabilities for sample 121000 / 255858
# [t-SNE] Computed conditional probabilities for sample 122000 / 255858
# [t-SNE] Computed conditional probabilities for sample 123000 / 255858
# [t-SNE] Computed conditional probabilities for sample 124000 / 255858
# [t-SNE] Computed conditional probabilities for sample 125000 / 255858
# [t-SNE] Computed conditional probabilities for sample 126000 / 255858
# [t-SNE] Computed conditional probabilities for sample 127000 / 255858
# [t-SNE] Computed conditional probabilities for sample 128000 / 255858
# [t-SNE] Computed conditional probabilities for sample 129000 / 255858
# [t-SNE] Computed conditional probabilities for sample 130000 / 255858
# [t-SNE] Computed conditional probabilities for sample 131000 / 255858
# [t-SNE] Computed conditional probabilities for sample 132000 / 255858
# [t-SNE] Computed conditional probabilities for sample 133000 / 255858
# [t-SNE] Computed conditional probabilities for sample 134000 / 255858
# [t-SNE] Computed conditional probabilities for sample 135000 / 255858
# [t-SNE] Computed conditional probabilities for sample 136000 / 255858
# [t-SNE] Computed conditional probabilities for sample 137000 / 255858
# [t-SNE] Computed conditional probabilities for sample 138000 / 255858
# [t-SNE] Computed conditional probabilities for sample 139000 / 255858
# [t-SNE] Computed conditional probabilities for sample 140000 / 255858
# [t-SNE] Computed conditional probabilities for sample 141000 / 255858
# [t-SNE] Computed conditional probabilities for sample 142000 / 255858
# [t-SNE] Computed conditional probabilities for sample 143000 / 255858
# [t-SNE] Computed conditional probabilities for sample 144000 / 255858
# [t-SNE] Computed conditional probabilities for sample 145000 / 255858
# [t-SNE] Computed conditional probabilities for sample 146000 / 255858
# [t-SNE] Computed conditional probabilities for sample 147000 / 255858
# [t-SNE] Computed conditional probabilities for sample 148000 / 255858
# [t-SNE] Computed conditional probabilities for sample 149000 / 255858
# [t-SNE] Computed conditional probabilities for sample 150000 / 255858
# [t-SNE] Computed conditional probabilities for sample 151000 / 255858
# [t-SNE] Computed conditional probabilities for sample 152000 / 255858
# [t-SNE] Computed conditional probabilities for sample 153000 / 255858
# [t-SNE] Computed conditional probabilities for sample 154000 / 255858
# [t-SNE] Computed conditional probabilities for sample 155000 / 255858
# [t-SNE] Computed conditional probabilities for sample 156000 / 255858
# [t-SNE] Computed conditional probabilities for sample 157000 / 255858
# [t-SNE] Computed conditional probabilities for sample 158000 / 255858
# [t-SNE] Computed conditional probabilities for sample 159000 / 255858
# [t-SNE] Computed conditional probabilities for sample 160000 / 255858
# [t-SNE] Computed conditional probabilities for sample 161000 / 255858
# [t-SNE] Computed conditional probabilities for sample 162000 / 255858
# [t-SNE] Computed conditional probabilities for sample 163000 / 255858
# [t-SNE] Computed conditional probabilities for sample 164000 / 255858
# [t-SNE] Computed conditional probabilities for sample 165000 / 255858
# [t-SNE] Computed conditional probabilities for sample 166000 / 255858
# [t-SNE] Computed conditional probabilities for sample 167000 / 255858
# [t-SNE] Computed conditional probabilities for sample 168000 / 255858
# [t-SNE] Computed conditional probabilities for sample 169000 / 255858
# [t-SNE] Computed conditional probabilities for sample 170000 / 255858
# [t-SNE] Computed conditional probabilities for sample 171000 / 255858
# [t-SNE] Computed conditional probabilities for sample 172000 / 255858
# [t-SNE] Computed conditional probabilities for sample 173000 / 255858
# [t-SNE] Computed conditional probabilities for sample 174000 / 255858
# [t-SNE] Computed conditional probabilities for sample 175000 / 255858
# [t-SNE] Computed conditional probabilities for sample 176000 / 255858
# [t-SNE] Computed conditional probabilities for sample 177000 / 255858
# [t-SNE] Computed conditional probabilities for sample 178000 / 255858
# [t-SNE] Computed conditional probabilities for sample 179000 / 255858
# [t-SNE] Computed conditional probabilities for sample 180000 / 255858
# [t-SNE] Computed conditional probabilities for sample 181000 / 255858
# [t-SNE] Computed conditional probabilities for sample 182000 / 255858
# [t-SNE] Computed conditional probabilities for sample 183000 / 255858
# [t-SNE] Computed conditional probabilities for sample 184000 / 255858
# [t-SNE] Computed conditional probabilities for sample 185000 / 255858
# [t-SNE] Computed conditional probabilities for sample 186000 / 255858
# [t-SNE] Computed conditional probabilities for sample 187000 / 255858
# [t-SNE] Computed conditional probabilities for sample 188000 / 255858
# [t-SNE] Computed conditional probabilities for sample 189000 / 255858
# [t-SNE] Computed conditional probabilities for sample 190000 / 255858
# [t-SNE] Computed conditional probabilities for sample 191000 / 255858
# [t-SNE] Computed conditional probabilities for sample 192000 / 255858
# [t-SNE] Computed conditional probabilities for sample 193000 / 255858
# [t-SNE] Computed conditional probabilities for sample 194000 / 255858
# [t-SNE] Computed conditional probabilities for sample 195000 / 255858
# [t-SNE] Computed conditional probabilities for sample 196000 / 255858
# [t-SNE] Computed conditional probabilities for sample 197000 / 255858
# [t-SNE] Computed conditional probabilities for sample 198000 / 255858
# [t-SNE] Computed conditional probabilities for sample 199000 / 255858
# [t-SNE] Computed conditional probabilities for sample 200000 / 255858
# [t-SNE] Computed conditional probabilities for sample 201000 / 255858
# [t-SNE] Computed conditional probabilities for sample 202000 / 255858
# [t-SNE] Computed conditional probabilities for sample 203000 / 255858
# [t-SNE] Computed conditional probabilities for sample 204000 / 255858
# [t-SNE] Computed conditional probabilities for sample 205000 / 255858
# [t-SNE] Computed conditional probabilities for sample 206000 / 255858
# [t-SNE] Computed conditional probabilities for sample 207000 / 255858
# [t-SNE] Computed conditional probabilities for sample 208000 / 255858
# [t-SNE] Computed conditional probabilities for sample 209000 / 255858
# [t-SNE] Computed conditional probabilities for sample 210000 / 255858
# [t-SNE] Computed conditional probabilities for sample 211000 / 255858
# [t-SNE] Computed conditional probabilities for sample 212000 / 255858
# [t-SNE] Computed conditional probabilities for sample 213000 / 255858
# [t-SNE] Computed conditional probabilities for sample 214000 / 255858
# [t-SNE] Computed conditional probabilities for sample 215000 / 255858
# [t-SNE] Computed conditional probabilities for sample 216000 / 255858
# [t-SNE] Computed conditional probabilities for sample 217000 / 255858
# [t-SNE] Computed conditional probabilities for sample 218000 / 255858
# [t-SNE] Computed conditional probabilities for sample 219000 / 255858
# [t-SNE] Computed conditional probabilities for sample 220000 / 255858
# [t-SNE] Computed conditional probabilities for sample 221000 / 255858
# [t-SNE] Computed conditional probabilities for sample 222000 / 255858
# [t-SNE] Computed conditional probabilities for sample 223000 / 255858
# [t-SNE] Computed conditional probabilities for sample 224000 / 255858
# [t-SNE] Computed conditional probabilities for sample 225000 / 255858
# [t-SNE] Computed conditional probabilities for sample 226000 / 255858
# [t-SNE] Computed conditional probabilities for sample 227000 / 255858
# [t-SNE] Computed conditional probabilities for sample 228000 / 255858
# [t-SNE] Computed conditional probabilities for sample 229000 / 255858
# [t-SNE] Computed conditional probabilities for sample 230000 / 255858
# [t-SNE] Computed conditional probabilities for sample 231000 / 255858
# [t-SNE] Computed conditional probabilities for sample 232000 / 255858
# [t-SNE] Computed conditional probabilities for sample 233000 / 255858
# [t-SNE] Computed conditional probabilities for sample 234000 / 255858
# [t-SNE] Computed conditional probabilities for sample 235000 / 255858
# [t-SNE] Computed conditional probabilities for sample 236000 / 255858
# [t-SNE] Computed conditional probabilities for sample 237000 / 255858
# [t-SNE] Computed conditional probabilities for sample 238000 / 255858
# [t-SNE] Computed conditional probabilities for sample 239000 / 255858
# [t-SNE] Computed conditional probabilities for sample 240000 / 255858
# [t-SNE] Computed conditional probabilities for sample 241000 / 255858
# [t-SNE] Computed conditional probabilities for sample 242000 / 255858
# [t-SNE] Computed conditional probabilities for sample 243000 / 255858
# [t-SNE] Computed conditional probabilities for sample 244000 / 255858
# [t-SNE] Computed conditional probabilities for sample 245000 / 255858
# [t-SNE] Computed conditional probabilities for sample 246000 / 255858
# [t-SNE] Computed conditional probabilities for sample 247000 / 255858
# [t-SNE] Computed conditional probabilities for sample 248000 / 255858
# [t-SNE] Computed conditional probabilities for sample 249000 / 255858
# [t-SNE] Computed conditional probabilities for sample 250000 / 255858
# [t-SNE] Computed conditional probabilities for sample 251000 / 255858
# [t-SNE] Computed conditional probabilities for sample 252000 / 255858
# [t-SNE] Computed conditional probabilities for sample 253000 / 255858
# [t-SNE] Computed conditional probabilities for sample 254000 / 255858
# [t-SNE] Computed conditional probabilities for sample 255000 / 255858
# [t-SNE] Computed conditional probabilities for sample 255858 / 255858
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Computed conditional probabilities in 29.611s
# [t-SNE] Iteration 50: error = 124.5079193, gradient norm = 0.0000001 (50 iterations in 259.211s)
# [t-SNE] Iteration 100: error = 124.5079193, gradient norm = 0.0000027 (50 iterations in 265.897s)
# [t-SNE] Iteration 150: error = 124.2891846, gradient norm = 0.0006644 (50 iterations in 284.757s)
# [t-SNE] Iteration 200: error = 108.8144760, gradient norm = 0.0011124 (50 iterations in 235.891s)
# [t-SNE] Iteration 250: error = 100.7872772, gradient norm = 0.0007507 (50 iterations in 207.871s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 100.787277
# [t-SNE] Iteration 300: error = 5.9259109, gradient norm = 0.0007580 (50 iterations in 203.889s)
# [t-SNE] Iteration 350: error = 5.5967674, gradient norm = 0.0006112 (50 iterations in 202.021s)
# [t-SNE] Iteration 400: error = 5.2458601, gradient norm = 0.0004840 (50 iterations in 192.333s)
# [t-SNE] Iteration 450: error = 4.9302139, gradient norm = 0.0003913 (50 iterations in 192.057s)
# [t-SNE] Iteration 500: error = 4.6598568, gradient norm = 0.0003249 (50 iterations in 189.563s)
# [t-SNE] Iteration 550: error = 4.4272060, gradient norm = 0.0002757 (50 iterations in 188.379s)
# [t-SNE] Iteration 600: error = 4.2264547, gradient norm = 0.0002380 (50 iterations in 187.401s)
# [t-SNE] Iteration 650: error = 4.0514312, gradient norm = 0.0002086 (50 iterations in 187.147s)
# [t-SNE] Iteration 700: error = 3.8948717, gradient norm = 0.0001852 (50 iterations in 186.319s)
# [t-SNE] Iteration 750: error = 3.7544985, gradient norm = 0.0001663 (50 iterations in 187.659s)
# [t-SNE] Iteration 800: error = 3.6261730, gradient norm = 0.0001503 (50 iterations in 186.860s)
# [t-SNE] Iteration 850: error = 3.5104904, gradient norm = 0.0001371 (50 iterations in 185.255s)
# [t-SNE] Iteration 900: error = 3.4080653, gradient norm = 0.0001258 (50 iterations in 186.299s)
# [t-SNE] Iteration 950: error = 3.3141031, gradient norm = 0.0001160 (50 iterations in 187.460s)
# [t-SNE] Iteration 1000: error = 3.2262650, gradient norm = 0.0001076 (50 iterations in 187.794s)
# [t-SNE] KL divergence after 1000 iterations: 3.226265
# Done..
# Creating plot for this t-sne visualization..
# /usr/local/lib/python3.8/dist-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# saving this plot as image in present working directory...
# Done

# %% [markdown]
# # Entrega 04 - Model

# %% [markdown]
# en la etapa de modelo se construira 3 modelos que son: SVM (suport vector machine),random  forest y por ultimo el XG Boost (extreme gradient boosting) todos ellos utilizados para clasificacion y regresion

# %%
from sklearn.svm import SVC #utilizar SVM
from sklearn import metrics #para comprobar la precisión del modelo
from sklearn.metrics import classification_report, confusion_matrix, precision_score,roc_auc_score
from sklearn.model_selection import train_test_split #dividir en conjunto de entrenamiento y prueba.
from sklearn.ensemble import RandomForestClassifier #utilizar Random Forest
from sklearn import datasets #importar conjunto de datos
import xgboost as xgb #utilizar xgboost

# %% [markdown]
# aqui vemos un resumen de los datos que manejaremos

# %%
#datafinal = datafinal.drop(['time'], axis=1)
datafinal = datafinal.drop(['user'], axis=1)
datafinal.head()
# Out:
#      activity         x         y         z
# 0  Downstairs -0.752839  0.290428 -0.553064
# 1  Downstairs -0.087618  0.557067  0.254750
# 2  Downstairs -0.099318 -0.291792 -0.351850
# 3  Downstairs  0.303491 -2.534602 -0.129923
# 4  Downstairs  0.007652  0.393371 -0.534417

# %% [markdown]
# SVM
#
# empezaremos con el suport vector machine

# %% [markdown]
# separamos los datos esperados con los datos por analizar

# %%
x_svm=datafinal.iloc[:,1:4]
x_svm
# Out:
#                x         y         z
# 0      -0.752839  0.290428 -0.553064
# 1      -0.087618  0.557067  0.254750
# 2      -0.099318 -0.291792 -0.351850
# 3       0.303491 -2.534602 -0.129923
# 4       0.007652  0.393371 -0.534417
# ...          ...       ...       ...
# 288187  0.617716  0.970528 -0.627039
# 288188  1.769316  1.014405 -0.019533
# 288189  0.278420  0.665073  0.595038
# 288190  2.558221  2.023585 -0.228094
# 288191 -0.132746  0.768017 -0.877672
#
# [288192 rows x 3 columns]

# %%
y_svm=datafinal.iloc[:,0]
y_svm
# Out:
# 0         Downstairs
# 1         Downstairs
# 2         Downstairs
# 3         Downstairs
# 4         Downstairs
#              ...
# 288187       Walking
# 288188       Walking
# 288189       Walking
# 288190       Walking
# 288191       Walking
# Name: activity, Length: 288192, dtype: object

# %% [markdown]
# se empieza a dividir entre los datos de test y de train

# %%
x_train_svm, x_test_svm, y_train_svm, y_test_svm = train_test_split(x_svm, y_svm, test_size=0.30)

# %%
print("Tamaño de los datos de train: ", len(x_train_svm))
print("Tamaño de los datos de test: ", len(x_test_svm))
# Out:
# Tamaño de los datos de train:  201734
# Tamaño de los datos de test:  86458

# %%
print(x_train_svm.shape)
print(y_train_svm.shape)
print(x_test_svm.shape)
print(y_test_svm.shape)
# Out:
# (201734, 3)
# (201734,)
# (86458, 3)
# (86458,)

# %%
from sklearn.metrics import f1_score,accuracy_score

# %% [markdown]
# aplicamos el modelo a probar

# %%
model = SVC()
#Recomendación: Revisar los parámetros del clasificador https://scikit-learn.org/stable/modules/generated/sklearn.svm.LinearSVC.html?highlight=svm
model.fit(x_train_svm, y_train_svm)
# Out:
# SVC()

# %% [markdown]
# ocupamos los datos de prueba, que estos no se ocuparon para el entrenamiento

# %%
pred_svm = model.predict(x_test_svm)
#pred_svm_test = model.predict(x_train_svm)

# %%
#train_f1 = f1_score(pred_svm, y_train_svm)
#test_f1 = f1_score(pred_svm_test, y_test_svm)

# %% [markdown]
# hacemos un resumen de los resultados del modelo implementado en base a una matriz de confucion y la precision del modelo en base a los datos

# %%
print(classification_report(y_test_svm, pred_svm))
cm = confusion_matrix(y_test_svm, pred_svm)
print(cm)
acc_svm = metrics.accuracy_score(pred_svm, y_test_svm)
print('The accuracy of the SVM is:', acc_svm)
# Out:
#               precision    recall  f1-score   support
#
#   Downstairs       0.40      0.32      0.35     14244
#      Jogging       0.61      0.65      0.63     14426
#      Sitting       0.94      0.95      0.95     14635
#     Standing       0.64      0.99      0.77     14487
#     Upstairs       0.36      0.12      0.18     14204
#      Walking       0.38      0.46      0.42     14462
#
#     accuracy                           0.59     86458
#    macro avg       0.55      0.58      0.55     86458
# weighted avg       0.56      0.59      0.55     86458
#
# [[ 4528  1966   178  2450  1257  3865]
#  [ 1360  9380   391   308   485  2502]
#  [   26     4 13936   643    16    10]
#  [   51     4     0 14356    36    40]
#  [ 2836  2098   185  3009  1726  4350]
#  [ 2539  2044   108  1796  1277  6698]]
# The accuracy of the SVM is: 0.5855328598857249

# %% [markdown]
# el resultado que nos dio fue de un 59% de acierto

# %%
sns.heatmap(cm, annot=True, cbar=None, cmap="Blues")
plt.title("Confusion Matrix"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# ahora  vamos a aplicar el modelo de random forest

# %% [markdown]
# dividimos los datos resultantes con los datos a analizar

# %%
X_rf = datafinal.iloc[:, 1:4]
X_rf
# Out:
#                x         y         z
# 0      -0.752839  0.290428 -0.553064
# 1      -0.087618  0.557067  0.254750
# 2      -0.099318 -0.291792 -0.351850
# 3       0.303491 -2.534602 -0.129923
# 4       0.007652  0.393371 -0.534417
# ...          ...       ...       ...
# 288187  0.617716  0.970528 -0.627039
# 288188  1.769316  1.014405 -0.019533
# 288189  0.278420  0.665073  0.595038
# 288190  2.558221  2.023585 -0.228094
# 288191 -0.132746  0.768017 -0.877672
#
# [288192 rows x 3 columns]

# %%
y_rf = datafinal.iloc[:, 0]
y_rf
# Out:
# 0         Downstairs
# 1         Downstairs
# 2         Downstairs
# 3         Downstairs
# 4         Downstairs
#              ...
# 288187       Walking
# 288188       Walking
# 288189       Walking
# 288190       Walking
# 288191       Walking
# Name: activity, Length: 288192, dtype: object

# %% [markdown]
# se divide un 30% para los datos de prueba y el resto para el entrenamiento

# %%
X_train_rf, X_test_rf, y_train_rf, y_test_rf = train_test_split(X_rf, y_rf ,test_size = 0.3)

# %%
print("Size of training data: ", len(X_train_rf))
print("Size of test data: ", len(X_test_rf))
# Out:
# Size of training data:  201734
# Size of test data:  86458

# %%
print(X_train_rf.shape)
print(y_train_rf.shape)
print(X_test_rf.shape)
print(y_test_rf.shape)
# Out:
# (201734, 3)
# (201734,)
# (86458, 3)
# (86458,)

# %% [markdown]
# se aplica el modelo de random forest

# %%
classifier = RandomForestClassifier()
#Recomendación: Revisar los parámetros del clasificador https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html 

classifier.fit(X_train_rf, y_train_rf)
# Out:
# RandomForestClassifier()

# %% [markdown]
# se pone a prueba intentando predecir con los datos de prueba separado previamente

# %%
#Predicción de los resultados del conjunto de pruebas
y_pred_rf = classifier.predict(X_test_rf)

# %%
#Hacer la matriz de confusión
cm_rf = confusion_matrix(y_test_rf, y_pred_rf)
cm_rf
# Out:
# array([[ 5116,  2071,    33,   545,  3203,  3584],
#        [ 1745,  9109,    66,    66,  1351,  2022],
#        [   66,    56, 14150,    68,    61,    18],
#        [  291,    20,    17, 13652,   382,   164],
#        [ 3399,  2305,    58,   759,  4418,  3450],
#        [ 3206,  2111,    19,   333,  3032,  5512]])

# %%
print(classification_report(y_test_rf, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#   Downstairs       0.37      0.35      0.36     14552
#      Jogging       0.58      0.63      0.61     14359
#      Sitting       0.99      0.98      0.98     14419
#     Standing       0.89      0.94      0.91     14526
#     Upstairs       0.35      0.31      0.33     14389
#      Walking       0.37      0.39      0.38     14213
#
#     accuracy                           0.60     86458
#    macro avg       0.59      0.60      0.60     86458
# weighted avg       0.59      0.60      0.60     86458

# %%
sns.heatmap(cm_rf, annot=True, cbar=None, cmap="Blues")
plt.title("Confusion Matrix"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()

# %%
print('The accuracy of the Random forest is:',metrics.accuracy_score(y_pred_rf, y_test_rf))
# Out:
# The accuracy of the Random forest is: 0.6009507506534965

# %% [markdown]
# lo que nos dio una precision de un 60%

# %% [markdown]
# ahora  aplicar XGBoost

# %% [markdown]
# aca no nos sirve dividirlo como en las anteriores 2 (iloc) sino que hay que convertirlo en un formato de arreglos de tipo numpy

# %%
datafinal['activity'] = LabelEncoder().fit_transform(datafinal['activity'])
y_boost = datafinal['activity'].to_numpy()
y_boost
# Out:
# array([0, 0, 0, ..., 5, 5, 5])

# %%
x_boost = datafinal[['x','y','z']].to_numpy()
x_boost
# Out:
# array([[-0.75283873,  0.29042786, -0.55306368],
#        [-0.08761823,  0.55706749,  0.25475022],
#        [-0.09931808, -0.29179158, -0.35184996],
#        ...,
#        [ 0.2784202 ,  0.66507341,  0.59503809],
#        [ 2.55822114,  2.02358544, -0.22809382],
#        [-0.13274625,  0.76801656, -0.87767234]])

# %% [markdown]
# se hace el mismo procedimiento de dividir entre prueba y enttrenamiento

# %%
X_train_boost, X_test_boost, y_train_boost, y_test_boost = train_test_split(x_boost, y_boost, test_size=0.3)

# %%
print("Tamaño del dato de entrenamiento:",len(X_train_boost));
print("Tamaño de los datos de prueba:",len(X_test_boost));
# Out:
# Tamaño del dato de entrenamiento: 201734
# Tamaño de los datos de prueba: 86458

# %% [markdown]
# creacion de DMatrix

# %%
#Creación del formato de datos Xgboost DMatrix (a partir de los arreglos ya obtenidos)
d_boosttrain = xgb.DMatrix(X_train_boost, label=y_train_boost)
d_boosttest = xgb.DMatrix(X_test_boost, label=y_test_boost)

# %% [markdown]
# estos son los parametros que trabajara en el entrenamiento

# %%
parameters = {'eta': 0.3, 'objective': 'multi:softprob', 'num_class': 6, 'max_depth': 16}
num_round = 20

# %% [markdown]
# aca entramos en entrenar el modelo

# %%
#Entrenar el modelo
bst = xgb.train(parameters, d_boosttrain, num_round)

# %% [markdown]
# despues del entrenamiento del modelo predecimos las etiquetas de los datos de prueba

# %%
#predicción
preds = bst.predict(d_boosttest)

# %%
preds[:5]
# Out:
# array([[9.9516168e-02, 5.0075126e-01, 8.7087378e-03, 6.4472668e-03,
#         3.2248476e-01, 6.2091801e-02],
#        [2.7747890e-03, 1.4373672e-03, 9.9115467e-01, 8.1948756e-04,
#         2.1449802e-03, 1.6687337e-03],
#        [8.9020492e-04, 1.0691856e-03, 9.9597162e-01, 5.8990146e-04,
#         7.5765181e-04, 7.2137412e-04],
#        [2.0018732e-02, 9.0431321e-01, 3.0699091e-03, 3.0054154e-03,
#         6.4306483e-02, 5.2862912e-03],
#        [2.2981791e-02, 5.4367227e-03, 2.1620221e-03, 9.2606038e-01,
#         3.3823088e-02, 9.5360242e-03]], dtype=float32)

# %%
best_preds = np.asarray([np.argmax(line) for line in preds])

# %%
best_preds
# Out:
# array([1, 2, 2, ..., 2, 1, 2])

# %% [markdown]
# aca se hace un resumen con una matriz de confusion

# %%
#Hacer la matriz de confusión
m = confusion_matrix(y_test_boost, best_preds)
m
# Out:
# array([[ 5117,  1866,    51,   594,  3109,  3687],
#        [ 1713,  8741,    79,    86,  1364,  2420],
#        [   45,    49, 14258,    58,    61,    19],
#        [  189,     7,    20, 13824,   394,   101],
#        [ 3296,  1997,    60,   815,  4373,  3835],
#        [ 2978,  1811,    22,   362,  2864,  6193]])

# %%
sns.heatmap(m, annot=True, cbar=None, cmap="Blues")
plt.title("Confusion Matrix"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# y calculando el  puntaje de precision de modelo recien entrenado

# %%
#calculando la precisión 

print(accuracy_score(y_test_boost, best_preds))
print(classification_report(y_test_boost, best_preds))
# Out:
# 0.6073006546531263
#               precision    recall  f1-score   support
#
#            0       0.38      0.35      0.37     14424
#            1       0.60      0.61      0.61     14403
#            2       0.98      0.98      0.98     14490
#            3       0.88      0.95      0.91     14535
#            4       0.36      0.30      0.33     14376
#            5       0.38      0.44      0.41     14230
#
#     accuracy                           0.61     86458
#    macro avg       0.60      0.61      0.60     86458
# weighted avg       0.60      0.61      0.60     86458

# %% [markdown]
# y que nos dio un 60%

# %% [markdown]
# # Entrega 05 - Interpretar

# %% [markdown]
# **Interpretacion acerca de los resultados**
#
# el resultado que nos dio, en resumen fue de un 60% de exito en xgboost, un 60% para random forest y un 58% para SVM
#
#
# una interpretacion que se puede definir es que en el histograma de actividades por usuario, existe una inusual concentracion de siting en un usuario en especifico (usuario 20) por lo que puede explicar porque en la fase de prediccion los sitting le fue muy bien,pero en general no se ha logrado el objetivo de la hipotesis que es en conseguir un nivel de rendimiento superior del 95%
#
# con esto nos abre lo complejo que es manejar o controlar estos tipos de datos con diferentes tipos de comportamiento entre usuarios y por lo que si todos estos datos fueran de una misma persona o que solo nos quedaramos con un usuario el nivel de presicion seria mucho mayor que lo sacado
# tambien en la fase de exploracion, en los graficos de diagramas de cajas se obsserva que no se distingue un patron claro entre los valores x,y,z solo definir con una linea horizontal
# tambien otro grafico que se demostro un problema de dispersion especialmente de la actividad de standing concentrandose mas entre los valores 0 y 1
#
# ademas las actividades que peor resultado obtuvieron fueron walking y upstairs, segun creo y por los graficos de la fase de explorer (grafico de caja y tsne) es por sus valores no muy distintos
#
#
# **conclusiones**
#
# las conclusiones que se puede sacar de este trabajo es que una posible mejora en los resultado es en considerar la variable usuario para la preparacion de os datos ya que sin ello,yo creo, que la complejidad de predecir las actividades seran mucho mayor
